# %% [markdown]
# ## Excercise 1 - Practice with Set up and Exploring Data

# %%
#Import Pandas library

# %%
#From the Data folder, import the superstore dataset and store it in a dataframe named superstore_df
#Hint: Check the type of file before importing, Do you need to install any library to import the file?

# %%
#Checking how many rows and columns, non-null values are in the dataframe superstore_df

# %%
#Checking the data types of each column in the dataframe superstore_df

# %%
#Print out the screen all columns in objects and float64 data types

# %%
#Help me to rename the Customer ID column to Cust_ID, Customer Name to Cust_Name, and Postal Code to Zip_Code 
#in the superstore_df dataframe
#Check all columns in the dataframe again to confirm the changes have been made

# %%
#Could you help me to output the dataframe with the first 5 rows 
# and column at index position 1,7,8,9,13,14,16, 17,19

# %%
#Could you help me set the index of the dataframe to the column Order ID by using superstore_df.set_index() function?

# %%
#Could you help me to return the data with Order ID 'US-2017-169551', 'US-2017-169320','US-2017-169488'
#and only output column 'Order ID', 'Order Date', 'Country','State','Category', 'Sales', 'Quantity', 'Profit'?

# %%
#Did you recognize any errors? if yes, why? How can you fix it here?

# %%
#Could you help me to get the output of all rows where the profit is greater than 0
#and sales is greater than 800
#Then, sorting the values by Sales in descending order and State in ascending order
#Only output the columns 'Order ID', 'State','Category', 'Sales', 'Profit'

#Using loc to do this task
