# %% [markdown]
# For this week's challenge, let’s do a bit of data preparation using shoe inventory data!
#
# The following dataset contains a list of shoes with an ID, colors, and sizes available.
#
#
# For this challenge, you want to clean the inventory data and reorganize the list to have:
# - A new ID number
# - The size
# - A comment stating how many colors are available, and
# - Three columns for color
#
# Keep in mind that the names of the colors are separated by the sign /.

# %%
import pandas as pd

# %%
df = pd.read_csv('data/shoes.csv')

# %%
df.head()
# Out:
#                      id       colors      sizes
# 0  AWpyySsJAGTnQPR7wNt4        Black          8
# 1  AWpyyyb3AGTnQPR7wN-u        Taupe     6 M US
# 2  AWpyzlajAGTnQPR7wOX8        Black          5
# 3  AWpyxomE0U_gzG0hkA1q  Black/Multi  9.5 BM US
# 4  AWpyxChWJbEilcB6RhWx        White         11

# %%
df.describe()
# Out:
#                           id colors sizes
# count                   2000   2000  2000
# unique                  1995    630   210
# top     AWpd384iM263mwCq9Vgv  Black     8
# freq                       5    319   156

# %%
# Exploring to see whether the data is already one row per shoe. Seems like it's already *shoe level data*.
df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of                         id                colors          sizes
# 0     AWpyySsJAGTnQPR7wNt4                 Black              8
# 1     AWpyyyb3AGTnQPR7wN-u                 Taupe         6 M US
# 2     AWpyzlajAGTnQPR7wOX8                 Black              5
# 3     AWpyxomE0U_gzG0hkA1q           Black/Multi      9.5 BM US
# 4     AWpyxChWJbEilcB6RhWx                 White             11
# ...                    ...                   ...            ...
# 1995  AWpSxBRHM263mwCq8eLh  Black Synthetic/Gore           10 N
# 1996  AWpSvfvEM263mwCq8eF7                 White         US 8.5
# 1997  AWpS01sFJbEilcB6O9yN                 Taupe  7.5 Medium BM
# 1998  AWpSyw4E0U_gzG0hhdDo                 Black             10
# 1999  AWpSvGJ80U_gzG0hhc1C                   Tan   10 Medium BM
#
# [2000 rows x 3 columns]>

# %%
df['colors'].unique()
# Out:
# array(['Black', 'Taupe', 'Black/Multi', 'White',
#        'Metallic Multi Soft Leather', 'Denim Blue', 'Black / Silver',
#        'Black and White Combo', 'Navy/Charcoal', 'Black Multi',
#        'Light Brown', 'Natural Snk Pu', 'Black Leopard', 'Red',
#        'Black Knit Flexible Technical Fabric', 'Brown', 'Black Fabric',
#        'Florence Berry', 'Silver', 'Tan Brown', 'Black Patent',
#        'Black/White', 'Camel', 'Dark Red',
#        'White / Atomic Blue / Safety Yellow', 'Black Paris', 'Wine',
#        'Charcoal', 'GOLD/METALLIC/SMOOTH', 'Luggage', 'Tan',
#        'Brown Nubuck', 'By', 'Natural Beige', 'Ecru', 'Natural Leather',
#        'Dark Wine Red', 'Black Suede/Crackle Lizard Print Leather',
#        'Brown Printed Python',
#        'Black Rubberized PU/Ballistic Nylon/Faux Fur',
#        'Brown Tool Polyurethane/Gore', 'Black Lux Soft Leather',
#        'Black/White Patent', 'BLACK-PINK 9013', 'Florence Navy', 'Blue',
#        'Urban White', 'Black / White', 'Natural Satin',
#        'Clear/Smoke Synthetic', 'Silver / Pistachio / Pink Glow',
#        'Mysterioso / Black / Aluminum', 'Black Combo', 'White Leather',
#        'Chocolate Leather', 'Silver Metallic Faux Leather', 'Gg2', 'Gray',
#        'Covert Green', 'Tp', 'Navy Stretch Fabric', 'Gold',
#        'Black Leather', 'Carmel', 'Grape Fleck', 'Black Polyurethane',
#        'Black Suede', 'Cocoa Leather/Fabric', 'Black/Patent',
#        'Dark Blush', 'Chestnut', 'Birch / White', 'Black Crinkle Patent',
#        'Rainbow Multi Glitter/Black Matte Synthetic',
#        'Clear PVC/Multi/Fuchsia Chrome',
#        'Rainbow Multi Glitter/Neon White Synthetic',
#        'Clear PVC-Black/Black',
#        'Clear PVC-Black Rhinestones/Dark Pewter Chrome',
#        'Black Soft Full Grain Leather', 'Khaki Green',
#        'Black Vegan Leather', 'Blush Tripoli',
#        'Hot Pink Crinkle Pat-Glitter', 'BLACK', 'Pewter Multi',
#        'Tan Suede', 'White Soft Full Grain Leather', 'Beige',
#        'Black/Gold', 'Purple', 'Inca Gold/White',
#        'Pewter Bottom Clear Up', 'Luxe Pink / White', 'Clear/Clear Ombre',
#        'Rose Gold', 'White EVA', 'Dark Brown Suede', 'Black/White Canvas',
#        'Pewter', 'Pink', 'Cognac', 'White Leopard', 'Other',
#        'Silver Satin', 'Cognac Burnished Fabric', 'Floral', 'BONE',
#        'WHITE', 'SAND', 'Black Glitter/Black Glitter Synthetic',
#        'Grey Faux Suede/Faux Leather',
#        'Black Stretch Polyurethane/Black Matte',
#        'Silver Glitter/Silver Glitter Synthetic',
#        'Black Stretch Pu and Black Matte', 'Navy/Pink Suede',
#        'Aqua Leather', 'Sand', 'Denim Leather', 'Dark Grey Suede',
#        'Black Laser', 'Goldwash Metallic Soft Leather', 'Black leather',
#        'Fire Red Polyurethane', 'Nrgy Turquoise / Puma White',
#        'Black Microsuede', 'Green', 'Silver Jeweled Lycra',
#        'Theatrical Pink', 'Black Sparkle', 'Bone Suede', 'Olive Combo',
#        'Vanilla Ice / Red Bud', 'Ultra Magenta / Puma White',
#        'Cordovan/Black', 'Midnight Purple', 'Dark Purple / White / Black',
#        'Silver Sequins/Silver Chrome', 'Turquoise', 'White Snake',
#        'Purple Sequins/Purple Chrome', 'Black Hs001',
#        'Linen/Marshmallow Textile', 'Star White Organic Canvas', 'Grey',
#        'Olive', 'Dk Charcoal', 'Dark Charcoal Suede', 'Malbec',
#        'Inky Navy Polyurethane', 'BROWN', 'Red Stain Fabric',
#        'Wine Suede', 'Tmoro Nabuck', 'Midnight Lime',
#        'Brown Distressed Leather', 'Bronco Brown', 'Coconut Shell',
#        'Seal', 'Wine Fabric/Faux Suede',
#        'Pewter Distressed Metallic Faux Leather', 'Red Patent',
#        'Khaki Buck', 'Black Fabric/Faux Suede', 'Black/Athena',
#        'Mustard Imi Suede', 'Dark Grey Leather', 'Blk Pat', 'Black Satin',
#        'Sand Oiled Fabric', 'Denim Combo Faux Leather/Fabric',
#        'Black Snake', 'Dark Tan', 'Beige Snake',
#        'Navy / White,Navy/White', 'Grey Knit', 'Black Knit',
#        'Black Microfiber', 'Mauve Microfiber', 'Brown/Multi/Dis', 'Bm2',
#        'Fr3', 'Natural Paris', 'Aquarium / Phantom', 'Toffee',
#        'Black Soft Lizard Embossed Patent Suede Leather',
#        'Sky Blue Leather', 'Navy Leather', 'Stone', 'Wb2', 'Light Tan',
#        'Fuchsia', 'Black Smooth Leather', 'Black Nubuck Leather',
#        'Denim Oiled Fabric', 'Taupe Leather', 'Black Suede/Black Matte',
#        'Black Faux Leather/Black Matte', 'BEETROOT-SILVER', 'Blush Suede',
#        'Turquoise Glitter', 'Black Faux Leather and Neon MultiColor',
#        'White Smooth Leather', 'Brown Combo', 'Sky Blue Suede', 'Nude',
#        'Stone Nubuck Polyurethane', 'Grey Stretch Fabric',
#        'Black Stretch Fabric', 'Black Brushed Hologram and Clear', 'Bk',
#        'Hw2', 'Black-patent', 'Blush', 'Red Brushed Vegan Suede',
#        'White PU', 'Light/Gold', 'Taupe Suede',
#        'Shadow White Cow Leather', 'Black Oiled Fabric', 'Natural',
#        'Dark Brown', 'Clear PVC/Silver Multi Rhinestones',
#        'Red Stretch Patent', 'Cream', 'Cream Suede',
#        'Black Cow Suede Leather', 'Leopard', 'Whiskey',
#        'Black Oil PU Canvas', 'Doe Oiled Fabric', 'NavyBlue', 'Navy',
#        'Mid Green Combo', 'CHESTNUT', 'Cognac Oiled Fabric',
#        'Champagne Shimmer', 'Red Suede',
#        'Chestnut Nubuck Waterproof Polyurethane/Faux Fur',
#        'Black Brushed Vegan/Textured Wool', 'Gold Silver Metallic',
#        'Black Microbuck/Elastic', 'Clear', 'Denim Blue Canvas/Neon White',
#        'Purple Leather', 'Red Leather', 'Black Leather/Nylon',
#        'Dark Brown Tumbled Leather/Cow Suede', 'Cognac Leather',
#        'Sand Leather', 'Black Soft Mini Tumbled Leather', 'Pewter Combo',
#        'Sand Grey Cow Suede Leather', 'Navy Combo', 'Doe Cow Suede',
#        'Pewter Leather', 'Coal PU Canvas', 'Black Purple',
#        'Silver Iridescent', 'Tan Faux Leather', 'Champange', 'Black/Pink',
#        'Burgundy Rub-Off Leather', 'Taupe Suede/Faux Fur',
#        'Tobacco Embossed Fabric', 'Black / Gray', 'White/White',
#        'Puma Black-elderberry', 'Peach Beige Suede', 'Blue Coral',
#        'Black Vegan Leather/Patent/Multi PVC', 'NAVY',
#        'Rosy Polyurethane', 'Sage Mist/White/Tin Grey',
#        'White Stretch Patent', 'Flat Black', 'Ink Suede',
#        'Off White Veg Calf Leather', 'Whisper White', 'Cement',
#        'Hot Pink Stretch Patent', 'Taupe Faux Leather', 'Yellow',
#        'Indigo Suede', 'Black, Green', 'Dusty Mauve Microfiber',
#        'Black Micro Suede', 'Leopard Multi', 'Er3', 'BlackPU',
#        'Nero / Black', 'Black/Silver', 'Red and White',
#        'Black and Purple', 'Dk Brown',
#        'Black Faux Leather/Silver Multi Rhinestones',
#        'Black/Black Textile', 'Lotus/Marshmallow Textile',
#        'Black Multi Leather', 'Black Calf',
#        'Aluminum / Aquarium / Neon Lime',
#        'Red/Black Micro Suede/Faux Fur', 'Off White Burnished Suede',
#        'Bronze', 'Black/Black Stretch', 'Deb', 'Navy Crushed Leather',
#        'Light Blue', 'Charcoal Suede Smooth', 'Nude Leather',
#        'Brown Suede Smooth', 'Black Faux Suede',
#        'Black/Pewter Faux Suede', 'Red Mesh Fabric',
#        'Brown/Blue Fish Leather', 'Bomber/Bomber Fish Leather',
#        'Bomber/Turquoise Fish Leather', 'Bomber/Mahogany Leather',
#        'Bomber/Tan Leather', 'Grey Suedette', 'Pajama Blue',
#        'Dark Gray Nylon', 'Royal Nylon', 'Navy Smooth Synthetic',
#        'Espresso Smooth Synthetic', 'Mushroom', 'Taupe Open Toe',
#        'Truffle Taupe', 'Submarine Blue', 'Whisky Plain', 'Black Fur',
#        'Navy Blue', 'Navy Smooth Sueded Polyurethane',
#        'Sage Smooth Sueded Polyurethane', 'Olive Green Leather',
#        'Camel Leather', 'Hot Pink Fur', 'Rust', 'Turquoise Leather',
#        'Black Mango', 'Brown Mango', 'Tan Mango', 'Brown Mango31',
#        'Black Faux Leather', 'Navy Faux Leather', 'TAUPE', 'DENIM',
#        'Olive Oiled Fabric', 'Black Smooth Burnished Polyurethane',
#        'Charcoal Smooth Burnish Polyurethane', 'Mocha', 'Dark Taupe',
#        'Black Stretch PU', 'Black Suede PU', 'Blue Denim',
#        'Black Cow Suede', 'Dark Taupe Cow Suede', 'Dark Grey Cow Suede',
#        'Brandy Suede', 'Brown Snake Polyurethane', 'Black Lyte',
#        'Grey91013', 'Black90002', 'Black Pandora Leather',
#        'White Pandora Leather', 'Black Stretch Patent/Black', 'CHOCOLATE',
#        'Wine Embossed Velvet', 'Black Embossed Velvet',
#        'Burgundy Lizard Fabric', 'Brown Lizard Fabric',
#        'Black Lizard Fabric', 'Oxblood', 'Tan ELMAA-02', 'Shiny Navy',
#        'Black Croc Texture', 'Navy Combo Fabric',
#        'Light Grey Combo Fabric', 'White Faux Leather', 'Camo', 'Emerald',
#        'Merino Leaf', 'Forest', 'Rioja / Olive', 'Peat Leather',
#        'Pack Green Microfiber', 'LIME', 'DARK PURPLE', 'Black-suede',
#        'OLIVE', 'Army', 'Black Velvet', 'Army Suede', 'Midnight',
#        'OL/PPL/ASH', 'Red Snake PU', 'Green Lime Snake PU',
#        'Gray and Blue', 'Augergine', 'Pine', 'Camel Suede', 'Olive Suede',
#        'Dark Olive', 'Burgundy', 'Black NBPU',
#        'Bordeaux Vegetable Leather', 'Navy Vegetable Leather',
#        'Hazelnut Suedette Fabric', 'COAL SUEDE', 'Deep Moss Leather',
#        'Grey Leather', 'WINE', 'Muir Green', 'Smokey Brown',
#        'Black Brushed Polyurethane', 'Black Versailles', 'Woodland',
#        'Whiskey Suede', 'PEAT SUEDE', 'Black/Tan Rubber', 'Regal red',
#        'CAMEL', 'LEOPARD', 'micro suede', 'Brown Leatherette',
#        'Ash Brown', 'Buff', 'Pewter Antique Metallic Leather',
#        'Dark Tan Faux Leather', 'Dark Pewter', 'Ruby Red Suede',
#        'Bronze Fabric', 'Black/Black', 'Fawn', 'Black Pu', 'Gray and Tan',
#        'Beige Snake Print Metallic Leather', 'WhitePU', 'BlackPatent',
#        'Fuschia', 'Black Stretch Suede', 'New Blush', 'Dark/Dust Suede',
#        'Dove', 'Chipmunk', 'Black Suedette', 'Fossil', 'Smokey Grey',
#        'Grey Multi Leather', 'Sea Salt', 'Denim Denim Canvas',
#        'Dark Natural', 'Women Short-Sleeve-Crewneck-T-Shirt',
#        'Whiskey Lonestar Pu', 'Antracite', 'Grey Velvet', 'Tribal Red',
#        'Chocolate', 'Orange', 'Brown/Glitter', 'Gold Leather', 'SILVER',
#        'Navy Satin', 'Champagne Satin', 'Pewter Shimmer',
#        'Silver Shimmer', 'Black Shimmer', 'Black/Microfiber',
#        'Silver/Glitter', 'Black suede', 'Caramel', 'Dark Grey',
#        'Black/Tan Full Grain Leather/Kid Suede', 'Light Tan Suede',
#        'Taupe Calf', 'Bone Smooth Leather', 'Silver Mesh', 'Porcini',
#        'Safari Gold', 'Bone Leather', 'Black Nubuck',
#        'Black Suede/Patent', 'Black Metallic', 'Black White Combo Fabric',
#        'Bone Combo Fabric', 'Light Blush Leather', 'Lt Blue Denim',
#        'Rose', 'Mustard', 'Floral Combo Fabric', 'Soft Taupe',
#        'Pewter Metallic Snake Pu', 'Brown Calf', 'Black Plaid', 'Berry',
#        'Gold Snake', 'Cocoa Brown Suede', 'BLUE', 'Dark Chocolate/Black',
#        'Steel Grey', 'Dark Gray Combo Fabric', 'Nude Sparkle',
#        'Taupe Fabric', 'Polo Tan', 'Silver Sparkle', 'Light Grey Combo',
#        'Navy / White', 'Grey Suede', 'Nude-Le', 'Silver Glitter PU',
#        'Dark Tan Leather',
#        'Black Smooth Waterproof Polyurethane/Faux Fur', 'Mulberry',
#        'navy texture', 'Sand Super Suede', 'Sand Nubuck Leather',
#        'Red Nubuck Leather', 'Vino', 'Black Synthetic',
#        'Lite Grey / Lite Grey / White / Lite Grey', 'Leopard Patent',
#        'Lite Gold Metallic', 'Black Peau De Soire', 'Navy / Teal',
#        'Beige Python', 'Stack Blue', 'Dark Beige', 'Charcoal Leather',
#        'Brown/Brown Leather/Serpent', 'Chocolate II',
#        'Black/Black Tooling', 'Denim/Gore', 'Dark Blue', 'Chestnut Brown',
#        'Black PU', 'White Smooth PU', 'Multicolor', 'Nude Patent',
#        'Black Patent Pu', 'Claret', 'Black Suede/Faux Fur',
#        'Umber / Red Dhalia', 'White Patent', 'Dark Beige Patent', 'PINK',
#        'Lipstick Red Patent', 'Coal', 'Elk / Black', 'Olive Drab',
#        'Black / Stone', 'Natural Fabric', 'Medium Natural',
#        'Dark Natural Fabric', 'Golden Cognac', 'Lt Gold Leather',
#        'BLUSH MULTI', 'Khaki', 'Chambray Blue Comb Fabric',
#        'White/Silver', 'Black Full Grain Leather',
#        'Black Croco Stamp/Patent', 'Cyclone Rainbow Leather',
#        'Country Road Leather', 'Dusty Pink', 'Mustard Microfiber',
#        'Grey Mesh Fabric', 'Black Rose Gold', 'Black Lamy Polyurethane',
#        'Tan Pu', 'CLEAR', 'Off White', 'Bronco Brown/Sage',
#        'Blush Microbuck/Elastic',
#        'Graphite/Dark Grey Cow Suede/Full Grain Leather', 'Blue Leather',
#        'Charcoal Brushed Vegan Suede', 'Electric Violet Nubuck Leather',
#        'Black Soft Nappa Leather', 'Slate', 'Rose Gold Leather',
#        'Red Plaid Brushed Vegan Shimmer Suede/Rubber',
#        'Taupe Multi Polyurethane', 'Brown Multi Leather',
#        'Lemon Lime Faux Fur', 'Green Multi', 'Seashell Pink',
#        'White Floral Faux Leather', 'Florensic Files',
#        'Bob and Weave Leather', 'Finley Leather', 'Alegria Grey',
#        'Chirpy Pewter Leather', 'Wild Child Blues Knit Fabric',
#        'Black Knit Fabric', 'Mandala Natural Leather',
#        'Anise Baby Tumble Leather', 'Oasis Natural Leather',
#        'White Multi Leather', 'Black Embossed Fabric', 'Topo',
#        'Black Satin/Lace', 'Camel Combo Suede/Faux Leather',
#        'Black Combo Fabric/Faux Leather', 'Natural Snake Printed Leather',
#        'Light Taupe', 'Mint', 'Silver Glitter', 'Tan Plaid', 'GOLD',
#        'TAN/LEOPARD', 'Black Snake Print', 'Black / Purple',
#        'MultiColored', 'Azalea Suede', 'Black2', 'Kork Fabric',
#        'Natural/Tan Soft Leather', 'Gray,Taupe',
#        'Black Vegan Leather/Black Hologram', 'Nutmeg', 'Gold Sequins',
#        'Grey/Black', 'Dusty Gold Leather', 'Silver/Gunmetal Leather',
#        'Robin Egg Blue', 'Black Texture Knit', 'Parachute Purple',
#        'Taupe Gray', 'Ivory', 'Black Stretch Pat and Black',
#        'Black Synthetic/Gore'], dtype=object)

# %%
# Splitting colors column with str.split 
df['colorset'] = df['colors'].str.split('/').apply(set)

# %%
df.head()
# Out:
#                      id       colors      sizes        colorset
# 0  AWpyySsJAGTnQPR7wNt4        Black          8         {Black}
# 1  AWpyyyb3AGTnQPR7wN-u        Taupe     6 M US         {Taupe}
# 2  AWpyzlajAGTnQPR7wOX8        Black          5         {Black}
# 3  AWpyxomE0U_gzG0hkA1q  Black/Multi  9.5 BM US  {Black, Multi}
# 4  AWpyxChWJbEilcB6RhWx        White         11         {White}

# %%
# Turning the set into a list, because python can't really split a set up
df['colorlist'] = df['colorset'].apply(list)

# %%
df[['color1', 'color2', 'color3', 'color4']] = pd.DataFrame(df['colorlist'].tolist(), index=df.index)

# %%
df.head()
# Out:
#                      id       colors      sizes        colorset  num_colors  \
# 0  AWpyySsJAGTnQPR7wNt4        Black          8         {Black}           1
# 1  AWpyyyb3AGTnQPR7wN-u        Taupe     6 M US         {Taupe}           1
# 2  AWpyzlajAGTnQPR7wOX8        Black          5         {Black}           1
# 3  AWpyxomE0U_gzG0hkA1q  Black/Multi  9.5 BM US  {Black, Multi}           2
# 4  AWpyxChWJbEilcB6RhWx        White         11         {White}           1
#
#         colorlist color1 color2 color3 color4
# 0         [Black]  Black   None   None   None
# 1         [Taupe]  Taupe   None   None   None
# 2         [Black]  Black   None   None   None
# 3  [Black, Multi]  Black  Multi   None   None
# 4         [White]  White   None   None   None

# %%
# Okay why did I need to do four columns though?
df['color4'].unique()
# Out:
# array([None, ' Lite Grey '], dtype=object)

# %%
df['colorset']
# Out:
# 0                       {Black}
# 1                       {Taupe}
# 2                       {Black}
# 3                {Black, Multi}
# 4                       {White}
#                  ...
# 1995    {Gore, Black Synthetic}
# 1996                    {White}
# 1997                    {Taupe}
# 1998                    {Black}
# 1999                      {Tan}
# Name: colorset, Length: 2000, dtype: object

# %%
# Getting number of colors
df['num_colors'] = df['colorset'].apply(len)

# %%
df.head()
# Out:
#                      id       colors      sizes        colorset  num_colors
# 0  AWpyySsJAGTnQPR7wNt4        Black          8         {Black}           1
# 1  AWpyyyb3AGTnQPR7wN-u        Taupe     6 M US         {Taupe}           1
# 2  AWpyzlajAGTnQPR7wOX8        Black          5         {Black}           1
# 3  AWpyxomE0U_gzG0hkA1q  Black/Multi  9.5 BM US  {Black, Multi}           2
# 4  AWpyxChWJbEilcB6RhWx        White         11         {White}           1
