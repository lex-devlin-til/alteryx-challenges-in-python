# %% [markdown]
# As the year wraps up, your role as a business analyst at a rapidly growing start-up takes a new turn. The VP of Finance has reached out, seeking help with the massive general ledger (GL) data that has grown beyond what the financial analysts can manage in Excel. Your task? Automate the workflow to create a consolidated Profit and Loss (P&L) statement for monthly reporting.
#
# You have been provided with 2024’s GL data and the chart of accounts. Now, it’s it is your job to organize the transaction data monthly according to the GL classes to streamline the financial reporting process.

# %%
import pandas as pd
import numpy as np
import os

path = r'G:\My Drive\Python Challenges\Alteryx Challenges in Python\457'

gl = pd.read_csv(os.path.join(path, 'General Ledger Data.csv'), index_col = False)

accounts = pd.read_csv(os.path.join(path, 'Chart of Accounts.csv'), index_col = False)

# %%
gl.head()
# Out:
#    EntryNo        Date  Territory_key  Account_key          Details  Amount
# 0      1.1  2024-01-01              1          230    Cost of Sales    -884
# 1      2.1  2024-01-01              1          230    Cost of Sales   -1120
# 2      3.1  2024-01-01              1          280  Credit Expenses   -2394
# 3      4.1  2024-01-01              1          210     Credit Sales    2948
# 4      5.1  2024-01-01              1          210       Cash Sales    3734

# %%
gl.value_counts()
# Out:
# EntryNo  Date        Territory_key  Account_key  Details                     Amount
# 1.1      2024-01-01  1              230          Cost of Sales               -884      1
# 1321.1   2019-12-31  4              380          Depreciation for the month  -5950     1
#                      6              380          Depreciation for the month  -4900     1
#                      7              380          Depreciation for the month  -4900     1
#          2020-01-01  1              210          Cash Sales                   8065     1
#                                                                                       ..
# 657.1    2019-01-01  1              230          Cost of Sales               -1370     1
#                      2              230          Cost of Sales               -343      1
#                      5              230          Cost of Sales               -445      1
#                      6              230          Cost of Sales               -856      1
# 1992.3   2020-12-30  7              420          Sale of asset                778      1
# Name: count, Length: 9660, dtype: int64

# %%
accounts.head(20)
# Out:
#     Account_key           Report                        Class  \
# 0           210  Profit and Loss                        Sales
# 1           220  Profit and Loss                        Sales
# 2           230  Profit and Loss                Cost of Sales
# 3           240  Profit and Loss           Operating Expenses
# 4           250  Profit and Loss           Operating Expenses
# 5           260  Profit and Loss           Operating Expenses
# 6           270  Profit and Loss           Operating Expenses
# 7           280  Profit and Loss           Operating Expenses
# 8           290  Profit and Loss           Operating Expenses
# 9           300  Profit and Loss           Operating Expenses
# 10          310  Profit and Loss           Operating Expenses
# 11          320  Profit and Loss           Operating Expenses
# 12          330  Profit and Loss           Operating Expenses
# 13          340  Profit and Loss           Operating Expenses
# 14          350  Profit and Loss           Operating Expenses
# 15          360  Profit and Loss           Operating Expenses
# 16          370  Profit and Loss  Depreciation & Amortization
# 17          380  Profit and Loss  Depreciation & Amortization
# 18          390  Profit and Loss  Depreciation & Amortization
# 19          400  Profit and Loss  Depreciation & Amortization
#
#                               Account
# 0                               Sales
# 1                        Sales Return
# 2                       Cost of Sales
# 3                         Staff Costs
# 4                    Bad Debt Expense
# 5                         Commissions
# 6                         Conferences
# 7                      Advertisements
# 8                              Travel
# 9                       Entertainment
# 10                    Office Supplies
# 11              Professional Services
# 12                          Telephone
# 13                          Utilities
# 14                     Other Expenses
# 15                               Rent
# 16                           Vehicles
# 17                          Equipment
# 18             Furniture and Fixtures
# 19  Amortization of Intangible Assets

# %%
df = gl.merge(accounts, how='left', on=['Account_key'])

# %%
df.head()
# Out:
#    EntryNo        Date  Territory_key  Account_key          Details  Amount  \
# 0      1.1  2024-01-01              1          230    Cost of Sales    -884
# 1      2.1  2024-01-01              1          230    Cost of Sales   -1120
# 2      3.1  2024-01-01              1          280  Credit Expenses   -2394
# 3      4.1  2024-01-01              1          210     Credit Sales    2948
# 4      5.1  2024-01-01              1          210       Cash Sales    3734
#
#             Report               Class         Account
# 0  Profit and Loss       Cost of Sales   Cost of Sales
# 1  Profit and Loss       Cost of Sales   Cost of Sales
# 2  Profit and Loss  Operating Expenses  Advertisements
# 3  Profit and Loss               Sales           Sales
# 4  Profit and Loss               Sales           Sales

# %%
# Lazy way of taking month and year
df['Year'] = df['Date'].str[0:4]
df['Month'] = df['Date'].str[5:7]

# %%
# Filter results to just 2024 data
df24 = df.loc[df['Year']=='2024']

# %%
df24.head()
# Out:
#    EntryNo        Date  Territory_key  Account_key          Details  Amount  \
# 0      1.1  2024-01-01              1          230    Cost of Sales    -884
# 1      2.1  2024-01-01              1          230    Cost of Sales   -1120
# 2      3.1  2024-01-01              1          280  Credit Expenses   -2394
# 3      4.1  2024-01-01              1          210     Credit Sales    2948
# 4      5.1  2024-01-01              1          210       Cash Sales    3734
#
#             Report               Class         Account Month Year  Year Month
# 0  Profit and Loss       Cost of Sales   Cost of Sales    2024-01  2024    01
# 1  Profit and Loss       Cost of Sales   Cost of Sales    2024-01  2024    01
# 2  Profit and Loss  Operating Expenses  Advertisements    2024-01  2024    01
# 3  Profit and Loss               Sales           Sales    2024-01  2024    01
# 4  Profit and Loss               Sales           Sales    2024-01  2024    01

# %%
from datetime import datetime

# %%
# Deriving month names
df['Month Name'] = pd.to_datetime(df['Date'], format='%Y-%m-%d').dt.strftime('%B')

# %%
df.head()
# Out:
#    EntryNo        Date  Territory_key  Account_key          Details  Amount  \
# 0      1.1  2024-01-01              1          230    Cost of Sales    -884
# 1      2.1  2024-01-01              1          230    Cost of Sales   -1120
# 2      3.1  2024-01-01              1          280  Credit Expenses   -2394
# 3      4.1  2024-01-01              1          210     Credit Sales    2948
# 4      5.1  2024-01-01              1          210       Cash Sales    3734
#
#             Report               Class         Account Month Year  Year Month  \
# 0  Profit and Loss       Cost of Sales   Cost of Sales    2024-01  2024    01
# 1  Profit and Loss       Cost of Sales   Cost of Sales    2024-01  2024    01
# 2  Profit and Loss  Operating Expenses  Advertisements    2024-01  2024    01
# 3  Profit and Loss               Sales           Sales    2024-01  2024    01
# 4  Profit and Loss               Sales           Sales    2024-01  2024    01
#
#   Month Name
# 0    January
# 1    January
# 2    January
# 3    January
# 4    January

# %%
solution = df.pivot_table(values='Amount', index='Class', columns='Month Name', aggfunc='sum')

# %%
# Yeowch, they're totally out of order
solution
# Out:
# Month Name                       April     August   December  February  \
# Class
# Cost of Sales                -362082.0  -539100.0  -588184.0 -212342.0
# Depreciation & Amortization  -137825.0  -137825.0  -137825.0 -137825.0
# Dividend                           NaN        NaN        NaN       NaN
# Exchange Loss/Gain              1163.0     -348.0      456.0     317.0
# Gain/Loss on Sales of Asset        NaN        NaN    16286.0       NaN
# Interest                         637.0    -1889.0      110.0    3180.0
# Operating Expenses           -481339.0  -576509.0  -399224.0 -445218.0
# Sales                        1103670.0  1713521.0  1867480.0  651190.0
# Tax                           -19486.0   -79868.0  -129231.0   33171.0
#
# Month Name                     January       July       June     March  \
# Class
# Cost of Sales                -333820.0  -558773.0  -339505.0 -286774.0
# Depreciation & Amortization  -137825.0  -137825.0  -137825.0 -137825.0
# Dividend                           NaN        NaN        NaN       NaN
# Exchange Loss/Gain               988.0     1072.0      487.0    1699.0
# Gain/Loss on Sales of Asset        NaN        NaN        NaN       NaN
# Interest                        -657.0    -1203.0     -424.0    1794.0
# Operating Expenses           -466506.0  -618477.0  -512179.0 -523234.0
# Sales                        1046468.0  1777538.0  1067888.0  894417.0
# Tax                            -9846.0   -86142.0    -8001.0   22898.0
#
# Month Name                         May   November    October  September
# Class
# Cost of Sales                -345751.0  -735648.0  -591033.0  -522478.0
# Depreciation & Amortization  -137825.0  -137825.0  -137825.0  -137825.0
# Dividend                           NaN    67698.0        NaN        NaN
# Exchange Loss/Gain              1368.0     1555.0     1758.0      420.0
# Gain/Loss on Sales of Asset        NaN        NaN        NaN        NaN
# Interest                        -183.0     -798.0    -1161.0    -1265.0
# Operating Expenses           -569877.0  -590561.0  -554415.0  -563058.0
# Sales                        1120884.0  2384673.0  1831216.0  1649697.0
# Tax                            -5809.0  -167649.0   -96507.0   -68297.0

# %%
# Taking list of unique months
month_order = df['Month Name'].unique()

# %%
month_order
# Out:
# array(['January', 'February', 'March', 'April', 'May', 'June', 'July',
#        'August', 'September', 'October', 'November', 'December'],
#       dtype=object)

# %%
# Doing some nonsense that ascribes the order they're currently in to the column itself
df['Month Name'] = pd.Categorical(df['Month Name'], categories=month_order, ordered=True)

# %%
# Now that the column has an "intrinsic" order, pivot_table sorts the columns by that order instead of alphabetical like default
solution = df.pivot_table(values='Amount', index='Class', columns='Month Name', aggfunc='sum')

# %%
solution
# Out:
# Month Name                   January  February   March    April      May  \
# Class
# Cost of Sales                -333820   -212342 -286774  -362082  -345751
# Depreciation & Amortization  -137825   -137825 -137825  -137825  -137825
# Dividend                           0         0       0        0        0
# Exchange Loss/Gain               988       317    1699     1163     1368
# Gain/Loss on Sales of Asset        0         0       0        0        0
# Interest                        -657      3180    1794      637     -183
# Operating Expenses           -466506   -445218 -523234  -481339  -569877
# Sales                        1046468    651190  894417  1103670  1120884
# Tax                            -9846     33171   22898   -19486    -5809
#
# Month Name                      June     July   August  September  October  \
# Class
# Cost of Sales                -339505  -558773  -539100    -522478  -591033
# Depreciation & Amortization  -137825  -137825  -137825    -137825  -137825
# Dividend                           0        0        0          0        0
# Exchange Loss/Gain               487     1072     -348        420     1758
# Gain/Loss on Sales of Asset        0        0        0          0        0
# Interest                        -424    -1203    -1889      -1265    -1161
# Operating Expenses           -512179  -618477  -576509    -563058  -554415
# Sales                        1067888  1777538  1713521    1649697  1831216
# Tax                            -8001   -86142   -79868     -68297   -96507
#
# Month Name                   November  December
# Class
# Cost of Sales                 -735648   -588184
# Depreciation & Amortization   -137825   -137825
# Dividend                        67698         0
# Exchange Loss/Gain               1555       456
# Gain/Loss on Sales of Asset         0     16286
# Interest                         -798       110
# Operating Expenses            -590561   -399224
# Sales                         2384673   1867480
# Tax                           -167649   -129231

# %% [markdown]
# Per Claude:
# Is a DataFrame a collection of arrays?
# Conceptually, yes! Under the hood, pandas stores each column as a NumPy array (or similar structure), but wraps them with additional functionality like labels, indexing, and data type handling. So a DataFrame is like a collection of Series (1D structures), each backed by arrays, all sharing the same index.
